# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import sqlite3
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
#loading the necessary dataset
#loading the tmdb movies csv file
tmdb=pd.read_csv("tmdb.movies.csv")
tmdb
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
#creating a copy
tmdb1 = tmdb.copy(deep=True)
tmdb1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
#dropping unncessary columns
tmdb1.drop(["vote_average","vote_count","genre_ids","id"], axis=1,inplace=True)

# %%
tmdb1
# Out:
#        Unnamed: 0 original_language  \
# 0               0                en
# 1               1                en
# 2               2                en
# 3               3                en
# 4               4                en
# ...           ...               ...
# 26512       26512                en
# 26513       26513                en
# 26514       26514                en
# 26515       26515                en
# 26516       26516                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title
# 0      Harry Potter and the Deathly Hallows: Part 1
# 1                          How to Train Your Dragon
# 2                                        Iron Man 2
# 3                                         Toy Story
# 4                                         Inception
# ...                                             ...
# 26512                         Laboratory Conditions
# 26513                               _EXHIBIT_84xxx_
# 26514                                  The Last One
# 26515                                  Trailer Made
# 26516                                    The Church
#
# [26517 rows x 6 columns]

# %%
#renaming the unnamed column'
tmdb1.rename(columns={"Unnamed":"id"},inplace=True)

# %%
tmdb1
# Out:
#        Unnamed: 0 original_language  \
# 0               0                en
# 1               1                en
# 2               2                en
# 3               3                en
# 4               4                en
# ...           ...               ...
# 26512       26512                en
# 26513       26513                en
# 26514       26514                en
# 26515       26515                en
# 26516       26516                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title
# 0      Harry Potter and the Deathly Hallows: Part 1
# 1                          How to Train Your Dragon
# 2                                        Iron Man 2
# 3                                         Toy Story
# 4                                         Inception
# ...                                             ...
# 26512                         Laboratory Conditions
# 26513                               _EXHIBIT_84xxx_
# 26514                                  The Last One
# 26515                                  Trailer Made
# 26516                                    The Church
#
# [26517 rows x 6 columns]

# %%
tmdb1.rename(columns={"Unnamed: 0":"id"},inplace=True)

# %%
tmdb1
# Out:
#           id original_language                                original_title  \
# 0          0                en  Harry Potter and the Deathly Hallows: Part 1
# 1          1                en                      How to Train Your Dragon
# 2          2                en                                    Iron Man 2
# 3          3                en                                     Toy Story
# 4          4                en                                     Inception
# ...      ...               ...                                           ...
# 26512  26512                en                         Laboratory Conditions
# 26513  26513                en                               _EXHIBIT_84xxx_
# 26514  26514                en                                  The Last One
# 26515  26515                en                                  Trailer Made
# 26516  26516                en                                    The Church
#
#        popularity release_date                                         title
# 0          33.533   2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1          28.734   2010-03-26                      How to Train Your Dragon
# 2          28.515   2010-05-07                                    Iron Man 2
# 3          28.005   1995-11-22                                     Toy Story
# 4          27.920   2010-07-16                                     Inception
# ...           ...          ...                                           ...
# 26512       0.600   2018-10-13                         Laboratory Conditions
# 26513       0.600   2018-05-01                               _EXHIBIT_84xxx_
# 26514       0.600   2018-10-01                                  The Last One
# 26515       0.600   2018-06-22                                  Trailer Made
# 26516       0.600   2018-10-05                                    The Church
#
# [26517 rows x 6 columns]

# %%
tmdb1["popularity"]=tmdb1["popularity"].round(1)

# %%
tmdb1
# Out:
#           id original_language                                original_title  \
# 0          0                en  Harry Potter and the Deathly Hallows: Part 1
# 1          1                en                      How to Train Your Dragon
# 2          2                en                                    Iron Man 2
# 3          3                en                                     Toy Story
# 4          4                en                                     Inception
# ...      ...               ...                                           ...
# 26512  26512                en                         Laboratory Conditions
# 26513  26513                en                               _EXHIBIT_84xxx_
# 26514  26514                en                                  The Last One
# 26515  26515                en                                  Trailer Made
# 26516  26516                en                                    The Church
#
#        popularity release_date                                         title
# 0            33.5   2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1            28.7   2010-03-26                      How to Train Your Dragon
# 2            28.5   2010-05-07                                    Iron Man 2
# 3            28.0   1995-11-22                                     Toy Story
# 4            27.9   2010-07-16                                     Inception
# ...           ...          ...                                           ...
# 26512         0.6   2018-10-13                         Laboratory Conditions
# 26513         0.6   2018-05-01                               _EXHIBIT_84xxx_
# 26514         0.6   2018-10-01                                  The Last One
# 26515         0.6   2018-06-22                                  Trailer Made
# 26516         0.6   2018-10-05                                    The Church
#
# [26517 rows x 6 columns]

# %%
tmdb1["release_date"]= pd.to_datetime(tmdb1["release_date"]).dt.year

# %%
tmdb1
# Out:
#           id original_language                                original_title  \
# 0          0                en  Harry Potter and the Deathly Hallows: Part 1
# 1          1                en                      How to Train Your Dragon
# 2          2                en                                    Iron Man 2
# 3          3                en                                     Toy Story
# 4          4                en                                     Inception
# ...      ...               ...                                           ...
# 26512  26512                en                         Laboratory Conditions
# 26513  26513                en                               _EXHIBIT_84xxx_
# 26514  26514                en                                  The Last One
# 26515  26515                en                                  Trailer Made
# 26516  26516                en                                    The Church
#
#        popularity  release_date                                         title
# 0            33.5          2010  Harry Potter and the Deathly Hallows: Part 1
# 1            28.7          2010                      How to Train Your Dragon
# 2            28.5          2010                                    Iron Man 2
# 3            28.0          1995                                     Toy Story
# 4            27.9          2010                                     Inception
# ...           ...           ...                                           ...
# 26512         0.6          2018                         Laboratory Conditions
# 26513         0.6          2018                               _EXHIBIT_84xxx_
# 26514         0.6          2018                                  The Last One
# 26515         0.6          2018                                  Trailer Made
# 26516         0.6          2018                                    The Church
#
# [26517 rows x 6 columns]

# %%
#checking for missing values 
tmdb1.isna().sum()
# Out:
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# dtype: int64

# %%
#checking for duplicated values
tmdb1.duplicated().sum()
# Out:
# 0

# %%
bom=pd.read_csv("bom.movie_gross.csv")

# %%
bom
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
bom1 = bom.copy(deep=True)
bom1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
bom1.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
bom1.hist(bins=15,figsize=(6,6));

# %%
bom1["domestic_gross"]=bom1["domestic_gross"].fillna(bom1["domestic_gross"].median())

# %%
# Step 1: Remove commas from the 'foreign_gross' column
bom1['foreign_gross'] = bom1['foreign_gross'].replace({',': ''}, regex=True)

# Step 2: Convert the column to numeric values, using 'coerce' to handle errors
bom1['foreign_gross'] = pd.to_numeric(bom1['foreign_gross'], errors='coerce')

# Step 3: Replace NaN values with the median of the column
median_value = bom1['foreign_gross'].median()
bom1['foreign_gross'] = bom1['foreign_gross'].fillna(median_value)

# %%
bom1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# 0       652000000.0  2010
# 1       691300000.0  2010
# 2       664300000.0  2010
# 3       535700000.0  2010
# 4       513900000.0  2010
# ...             ...   ...
# 3382     18700000.0  2018
# 3383     18700000.0  2018
# 3384     18700000.0  2018
# 3385     18700000.0  2018
# 3386     18700000.0  2018
#
# [3387 rows x 5 columns]

# %%
#dropping unnecessary columns
bom1.drop(['studio'],axis=1,inplace=True)

# %%
bom1.isnull().sum().any()
# Out:
# False

# %%
bom1
# Out:
#                                             title  domestic_gross  \
# 0                                     Toy Story 3     415000000.0
# 1                      Alice in Wonderland (2010)     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     296000000.0
# 3                                       Inception     292600000.0
# 4                             Shrek Forever After     238700000.0
# ...                                           ...             ...
# 3382                                    The Quake          6200.0
# 3383                  Edward II (2018 re-release)          4800.0
# 3384                                     El Pacto          2500.0
# 3385                                     The Swan          2400.0
# 3386                            An Actor Prepares          1700.0
#
#       foreign_gross  year
# 0       652000000.0  2010
# 1       691300000.0  2010
# 2       664300000.0  2010
# 3       535700000.0  2010
# 4       513900000.0  2010
# ...             ...   ...
# 3382     18700000.0  2018
# 3383     18700000.0  2018
# 3384     18700000.0  2018
# 3385     18700000.0  2018
# 3386     18700000.0  2018
#
# [3387 rows x 4 columns]

# %%
#adding a new column
bom1["total_gross"]=bom1["domestic_gross"]+bom1["foreign_gross"]
bom1
# Out:
#                                             title  domestic_gross  \
# 0                                     Toy Story 3     415000000.0
# 1                      Alice in Wonderland (2010)     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     296000000.0
# 3                                       Inception     292600000.0
# 4                             Shrek Forever After     238700000.0
# ...                                           ...             ...
# 3382                                    The Quake          6200.0
# 3383                  Edward II (2018 re-release)          4800.0
# 3384                                     El Pacto          2500.0
# 3385                                     The Swan          2400.0
# 3386                            An Actor Prepares          1700.0
#
#       foreign_gross  year   total_gross
# 0       652000000.0  2010  1.067000e+09
# 1       691300000.0  2010  1.025500e+09
# 2       664300000.0  2010  9.603000e+08
# 3       535700000.0  2010  8.283000e+08
# 4       513900000.0  2010  7.526000e+08
# ...             ...   ...           ...
# 3382     18700000.0  2018  1.870620e+07
# 3383     18700000.0  2018  1.870480e+07
# 3384     18700000.0  2018  1.870250e+07
# 3385     18700000.0  2018  1.870240e+07
# 3386     18700000.0  2018  1.870170e+07
#
# [3387 rows x 5 columns]

# %%
#changing to currency for uniformity 
bom1['domestic_gross'] = bom1['domestic_gross'].apply(lambda x: f"${x:,.2f}")

# %%
bom1['foreign_gross'] = bom1['foreign_gross'].apply(lambda x: f"${x:,.2f}")

# %%
bom1['total_gross'] = bom1['total_gross'].apply(lambda x: f"${x:,.2f}")

# %%
bom1
# Out:
#                                             title   domestic_gross  \
# 0                                     Toy Story 3  $415,000,000.00
# 1                      Alice in Wonderland (2010)  $334,200,000.00
# 2     Harry Potter and the Deathly Hallows Part 1  $296,000,000.00
# 3                                       Inception  $292,600,000.00
# 4                             Shrek Forever After  $238,700,000.00
# ...                                           ...              ...
# 3382                                    The Quake        $6,200.00
# 3383                  Edward II (2018 re-release)        $4,800.00
# 3384                                     El Pacto        $2,500.00
# 3385                                     The Swan        $2,400.00
# 3386                            An Actor Prepares        $1,700.00
#
#         foreign_gross  year        total_gross
# 0     $652,000,000.00  2010  $1,067,000,000.00
# 1     $691,300,000.00  2010  $1,025,500,000.00
# 2     $664,300,000.00  2010    $960,300,000.00
# 3     $535,700,000.00  2010    $828,300,000.00
# 4     $513,900,000.00  2010    $752,600,000.00
# ...               ...   ...                ...
# 3382   $18,700,000.00  2018     $18,706,200.00
# 3383   $18,700,000.00  2018     $18,704,800.00
# 3384   $18,700,000.00  2018     $18,702,500.00
# 3385   $18,700,000.00  2018     $18,702,400.00
# 3386   $18,700,000.00  2018     $18,701,700.00
#
# [3387 rows x 5 columns]

# %%
#confirming the changes
bom1
# Out:
#                                             title   domestic_gross  \
# 0                                     Toy Story 3  $415,000,000.00
# 1                      Alice in Wonderland (2010)  $334,200,000.00
# 2     Harry Potter and the Deathly Hallows Part 1  $296,000,000.00
# 3                                       Inception  $292,600,000.00
# 4                             Shrek Forever After  $238,700,000.00
# ...                                           ...              ...
# 3382                                    The Quake        $6,200.00
# 3383                  Edward II (2018 re-release)        $4,800.00
# 3384                                     El Pacto        $2,500.00
# 3385                                     The Swan        $2,400.00
# 3386                            An Actor Prepares        $1,700.00
#
#         foreign_gross  year        total_gross
# 0     $652,000,000.00  2010  $1,067,000,000.00
# 1     $691,300,000.00  2010  $1,025,500,000.00
# 2     $664,300,000.00  2010    $960,300,000.00
# 3     $535,700,000.00  2010    $828,300,000.00
# 4     $513,900,000.00  2010    $752,600,000.00
# ...               ...   ...                ...
# 3382   $18,700,000.00  2018     $18,706,200.00
# 3383   $18,700,000.00  2018     $18,704,800.00
# 3384   $18,700,000.00  2018     $18,702,500.00
# 3385   $18,700,000.00  2018     $18,702,400.00
# 3386   $18,700,000.00  2018     $18,701,700.00
#
# [3387 rows x 5 columns]

# %%
#adding the id as the  first column
bom1.insert(0, 'id', range(1, len(bom1) + 1))

# %%
bom1
# Out:
#         id                                        title   domestic_gross  \
# 0        1                                  Toy Story 3  $415,000,000.00
# 1        2                   Alice in Wonderland (2010)  $334,200,000.00
# 2        3  Harry Potter and the Deathly Hallows Part 1  $296,000,000.00
# 3        4                                    Inception  $292,600,000.00
# 4        5                          Shrek Forever After  $238,700,000.00
# ...    ...                                          ...              ...
# 3382  3383                                    The Quake        $6,200.00
# 3383  3384                  Edward II (2018 re-release)        $4,800.00
# 3384  3385                                     El Pacto        $2,500.00
# 3385  3386                                     The Swan        $2,400.00
# 3386  3387                            An Actor Prepares        $1,700.00
#
#         foreign_gross  year        total_gross
# 0     $652,000,000.00  2010  $1,067,000,000.00
# 1     $691,300,000.00  2010  $1,025,500,000.00
# 2     $664,300,000.00  2010    $960,300,000.00
# 3     $535,700,000.00  2010    $828,300,000.00
# 4     $513,900,000.00  2010    $752,600,000.00
# ...               ...   ...                ...
# 3382   $18,700,000.00  2018     $18,706,200.00
# 3383   $18,700,000.00  2018     $18,704,800.00
# 3384   $18,700,000.00  2018     $18,702,500.00
# 3385   $18,700,000.00  2018     $18,702,400.00
# 3386   $18,700,000.00  2018     $18,701,700.00
#
# [3387 rows x 6 columns]

# %%
#loading the sql database
mvsql=sqlite3.connect("im.db")

# %%
#viewing the tables
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", mvsql)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
#loading the movie basics table from the sql database
mvbas=pd.read_sql("""SELECT * FROM movie_basics;""",mvsql)

# %%
mvbas
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#creating a new copy
mvbas1 = mvbas.copy(deep=True)
mvbas1
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#dropping unnecesary columns
mvbas1.drop(["original_title","runtime_minutes"],axis=1,inplace=True)

# %%
mvbas1
# Out:
#          movie_id                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#                       genres
# 0         Action,Crime,Drama
# 1            Biography,Drama
# 2                      Drama
# 3               Comedy,Drama
# 4       Comedy,Drama,Fantasy
# ...                      ...
# 146139                 Drama
# 146140           Documentary
# 146141                Comedy
# 146142                  None
# 146143           Documentary
#
# [146144 rows x 4 columns]

# %%
#renaming columns for uniformity
mvbas1.rename(columns={"movie_id":'id'},inplace=True)

# %%
mvbas1.rename(columns={"start_year":'year'},inplace=True)

# %%
mvbas1.rename(columns={"primary_title":'title'},inplace=True)

# %%
mvbas1
# Out:
#                id                                        title  year  \
# 0       tt0063540                                    Sunghursh  2013
# 1       tt0066787              One Day Before the Rainy Season  2019
# 2       tt0069049                   The Other Side of the Wind  2018
# 3       tt0069204                              Sabse Bada Sukh  2018
# 4       tt0100275                     The Wandering Soap Opera  2017
# ...           ...                                          ...   ...
# 146139  tt9916538                          Kuambil Lagi Hatiku  2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro  2015
# 146141  tt9916706                              Dankyavar Danka  2013
# 146142  tt9916730                                       6 Gunn  2017
# 146143  tt9916754               Chico Albuquerque - Revelações  2013
#
#                       genres
# 0         Action,Crime,Drama
# 1            Biography,Drama
# 2                      Drama
# 3               Comedy,Drama
# 4       Comedy,Drama,Fantasy
# ...                      ...
# 146139                 Drama
# 146140           Documentary
# 146141                Comedy
# 146142                  None
# 146143           Documentary
#
# [146144 rows x 4 columns]

# %%
#loading the movie rating table
mvrat=pd.read_sql("""SELECT * FROM movie_ratings;""",mvsql)

# %%
#creating a new copy
mvrat1= mvrat.copy(deep=True)

# %%
mvrat1
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#dropping unnecessary columns
mvrat1.drop(["numvotes"],axis=1,inplace=True)

# %%
#renaming columns
mvrat1.rename(columns={"movie_id":"id"},inplace=True)

# %%
mvrat1.rename(columns={"averagerating":"average_rating"},inplace=True)

# %%
mvrat1
# Out:
#                id  average_rating
# 0      tt10356526             8.3
# 1      tt10384606             8.9
# 2       tt1042974             6.4
# 3       tt1043726             4.2
# 4       tt1060240             6.5
# ...           ...             ...
# 73851   tt9805820             8.1
# 73852   tt9844256             7.5
# 73853   tt9851050             4.7
# 73854   tt9886934             7.0
# 73855   tt9894098             6.3
#
# [73856 rows x 2 columns]

# %%
# Merge tables from the sql which are relatabe specifying same column names (id)
merged_movies = pd.merge(mvbas1, mvrat1, left_on='id', right_on='id', how='inner')


print(merged_movies)
# Out:
#               id                            title  year                genres  \
# 0      tt0063540                        Sunghursh  2013    Action,Crime,Drama
# 1      tt0066787  One Day Before the Rainy Season  2019       Biography,Drama
# 2      tt0069049       The Other Side of the Wind  2018                 Drama
# 3      tt0069204                  Sabse Bada Sukh  2018          Comedy,Drama
# 4      tt0100275         The Wandering Soap Opera  2017  Comedy,Drama,Fantasy
# ...          ...                              ...   ...                   ...
# 73851  tt9913084                 Diabolik sono io  2019           Documentary
# 73852  tt9914286                Sokagin Çocuklari  2019          Drama,Family
# 73853  tt9914642                        Albatross  2017           Documentary
# 73854  tt9914942       La vida sense la Sara Amat  2019                  None
# 73855  tt9916160                       Drømmeland  2019           Documentary
#
#        average_rating
# 0                 7.0
# 1                 7.2
# 2                 6.9
# 3                 6.1
# 4                 6.5
# ...               ...
# 73851             6.2
# 73852             8.7
# 73853             8.5
# 73854             6.6
# 73855             6.5
#
# [73856 rows x 5 columns]

# %%
#changing into a dataframe
merged_movies_df=pd.DataFrame(merged_movies)
merged_movies_df
# Out:
#               id                            title  year                genres  \
# 0      tt0063540                        Sunghursh  2013    Action,Crime,Drama
# 1      tt0066787  One Day Before the Rainy Season  2019       Biography,Drama
# 2      tt0069049       The Other Side of the Wind  2018                 Drama
# 3      tt0069204                  Sabse Bada Sukh  2018          Comedy,Drama
# 4      tt0100275         The Wandering Soap Opera  2017  Comedy,Drama,Fantasy
# ...          ...                              ...   ...                   ...
# 73851  tt9913084                 Diabolik sono io  2019           Documentary
# 73852  tt9914286                Sokagin Çocuklari  2019          Drama,Family
# 73853  tt9914642                        Albatross  2017           Documentary
# 73854  tt9914942       La vida sense la Sara Amat  2019                  None
# 73855  tt9916160                       Drømmeland  2019           Documentary
#
#        average_rating
# 0                 7.0
# 1                 7.2
# 2                 6.9
# 3                 6.1
# 4                 6.5
# ...               ...
# 73851             6.2
# 73852             8.7
# 73853             8.5
# 73854             6.6
# 73855             6.5
#
# [73856 rows x 5 columns]

# %%
#Merging the tm1 dataset("tmdb.movies.csv") to the original merged data set
# First merge: Add tmdb1 to the existing merged DataFrame
merged_movies_final = pd.merge(merged_movies, tmdb1, on="title", how='inner')

# Second merge: Add bom1 to the updated merged DataFrame using the same column name
merged_movies_final = pd.merge(merged_movies, bom1, on='title', how='inner')

# Check the result
print(merged_movies_final.head())
# Out:
#         id_x                            title  year_x  \
# 0  tt0315642                            Wazir    2016
# 1  tt0337692                      On the Road    2012
# 2  tt4339118                      On the Road    2014
# 3  tt5647250                      On the Road    2016
# 4  tt0359950  The Secret Life of Walter Mitty    2013
#
#                     genres  average_rating  id_y  domestic_gross  \
# 0       Action,Crime,Drama             7.1  2569   $1,100,000.00
# 1  Adventure,Drama,Romance             6.1   905     $744,000.00
# 2                    Drama             6.0   905     $744,000.00
# 3                    Drama             5.7   905     $744,000.00
# 4   Adventure,Comedy,Drama             7.3  1170  $58,200,000.00
#
#      foreign_gross  year_y      total_gross
# 0   $18,700,000.00    2016   $19,800,000.00
# 1    $8,000,000.00    2012    $8,744,000.00
# 2    $8,000,000.00    2012    $8,744,000.00
# 3    $8,000,000.00    2012    $8,744,000.00
# 4  $129,900,000.00    2013  $188,100,000.00

# %%
#loading the dataframe
merged_movies_final_df=pd.DataFrame(merged_movies_final)
merged_movies_final_df
# Out:
#            id_x                            title  year_x  \
# 0     tt0315642                            Wazir    2016
# 1     tt0337692                      On the Road    2012
# 2     tt4339118                      On the Road    2014
# 3     tt5647250                      On the Road    2016
# 4     tt0359950  The Secret Life of Walter Mitty    2013
# ...         ...                              ...     ...
# 3022  tt8331988                  The Chambermaid    2018
# 3023  tt8404272           How Long Will I Love U    2018
# 3024  tt8427036                  Helicopter Eela    2018
# 3025  tt9078374                      Last Letter    2018
# 3026  tt9151704        Burn the Stage: The Movie    2018
#
#                        genres  average_rating  id_y  domestic_gross  \
# 0          Action,Crime,Drama             7.1  2569   $1,100,000.00
# 1     Adventure,Drama,Romance             6.1   905     $744,000.00
# 2                       Drama             6.0   905     $744,000.00
# 3                       Drama             5.7   905     $744,000.00
# 4      Adventure,Comedy,Drama             7.3  1170  $58,200,000.00
# ...                       ...             ...   ...             ...
# 3022                    Drama             7.1  2322         $300.00
# 3023                  Romance             6.5  3150     $747,000.00
# 3024                    Drama             5.4  3355      $72,000.00
# 3025            Drama,Romance             6.4  3320     $181,000.00
# 3026        Documentary,Music             8.8  3205   $4,200,000.00
#
#         foreign_gross  year_y      total_gross
# 0      $18,700,000.00    2016   $19,800,000.00
# 1       $8,000,000.00    2012    $8,744,000.00
# 2       $8,000,000.00    2012    $8,744,000.00
# 3       $8,000,000.00    2012    $8,744,000.00
# 4     $129,900,000.00    2013  $188,100,000.00
# ...               ...     ...              ...
# 3022   $18,700,000.00    2015   $18,700,300.00
# 3023   $82,100,000.00    2018   $82,847,000.00
# 3024   $18,700,000.00    2018   $18,772,000.00
# 3025   $18,700,000.00    2018   $18,881,000.00
# 3026   $16,100,000.00    2018   $20,300,000.00
#
# [3027 rows x 10 columns]

# %%
#dropping unecessary/repeated columns for the merged datasets
merged_movies_final_df.drop(columns=["id_x","year_x","id_y"],axis=1,inplace=True)

# %%
merged_movies_final_df
# Out:
#                                 title                   genres  \
# 0                               Wazir       Action,Crime,Drama
# 1                         On the Road  Adventure,Drama,Romance
# 2                         On the Road                    Drama
# 3                         On the Road                    Drama
# 4     The Secret Life of Walter Mitty   Adventure,Comedy,Drama
# ...                               ...                      ...
# 3022                  The Chambermaid                    Drama
# 3023           How Long Will I Love U                  Romance
# 3024                  Helicopter Eela                    Drama
# 3025                      Last Letter            Drama,Romance
# 3026        Burn the Stage: The Movie        Documentary,Music
#
#       average_rating  domestic_gross    foreign_gross  year_y      total_gross
# 0                7.1   $1,100,000.00   $18,700,000.00    2016   $19,800,000.00
# 1                6.1     $744,000.00    $8,000,000.00    2012    $8,744,000.00
# 2                6.0     $744,000.00    $8,000,000.00    2012    $8,744,000.00
# 3                5.7     $744,000.00    $8,000,000.00    2012    $8,744,000.00
# 4                7.3  $58,200,000.00  $129,900,000.00    2013  $188,100,000.00
# ...              ...             ...              ...     ...              ...
# 3022             7.1         $300.00   $18,700,000.00    2015   $18,700,300.00
# 3023             6.5     $747,000.00   $82,100,000.00    2018   $82,847,000.00
# 3024             5.4      $72,000.00   $18,700,000.00    2018   $18,772,000.00
# 3025             6.4     $181,000.00   $18,700,000.00    2018   $18,881,000.00
# 3026             8.8   $4,200,000.00   $16,100,000.00    2018   $20,300,000.00
#
# [3027 rows x 7 columns]

# %%
#checking for missing values
merged_movies_final_df.isna().sum()
# Out:
# title             0
# genres            7
# average_rating    0
# domestic_gross    0
# foreign_gross     0
# year_y            0
# total_gross       0
# dtype: int64

# %%
#filling the missing values
for column in merged_movies_final_df.select_dtypes(include=["object"]).columns:
    merged_movies_final_df[column].fillna(merged_movies_final_df[column].mode()[0],inplace=True)

# %%
#confirming changes
merged_movies_final_df.isna().sum()
# Out:
# title             0
# genres            0
# average_rating    0
# domestic_gross    0
# foreign_gross     0
# year_y            0
# total_gross       0
# dtype: int64

# %%
#renaming columns
merged_movies_final_df.rename({"year_y":"year"},axis=1,inplace=True)

# %%
merged_movies_final_df
# Out:
#                                 title                   genres  \
# 0                               Wazir       Action,Crime,Drama
# 1                         On the Road  Adventure,Drama,Romance
# 2                         On the Road                    Drama
# 3                         On the Road                    Drama
# 4     The Secret Life of Walter Mitty   Adventure,Comedy,Drama
# ...                               ...                      ...
# 3022                  The Chambermaid                    Drama
# 3023           How Long Will I Love U                  Romance
# 3024                  Helicopter Eela                    Drama
# 3025                      Last Letter            Drama,Romance
# 3026        Burn the Stage: The Movie        Documentary,Music
#
#       average_rating  domestic_gross    foreign_gross  year      total_gross
# 0                7.1   $1,100,000.00   $18,700,000.00  2016   $19,800,000.00
# 1                6.1     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 2                6.0     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 3                5.7     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 4                7.3  $58,200,000.00  $129,900,000.00  2013  $188,100,000.00
# ...              ...             ...              ...   ...              ...
# 3022             7.1         $300.00   $18,700,000.00  2015   $18,700,300.00
# 3023             6.5     $747,000.00   $82,100,000.00  2018   $82,847,000.00
# 3024             5.4      $72,000.00   $18,700,000.00  2018   $18,772,000.00
# 3025             6.4     $181,000.00   $18,700,000.00  2018   $18,881,000.00
# 3026             8.8   $4,200,000.00   $16,100,000.00  2018   $20,300,000.00
#
# [3027 rows x 7 columns]

# %%
#checking for outliers
sns.boxplot(merged_movies_final_df)
# Out:
# <Axes: >

# %%
#checking if all the necessary data is available
merged_movies_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3027 entries, 0 to 3026
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3027 non-null   object
#  1   genres          3027 non-null   object
#  2   average_rating  3027 non-null   float64
#  3   domestic_gross  3027 non-null   object
#  4   foreign_gross   3027 non-null   object
#  5   year            3027 non-null   int64
#  6   total_gross     3027 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 165.7+ KB

# %%
#loading the second dataset
rt = pd.read_csv("rt.movie_info.tsv",delimiter="\t")
rt
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
#creating a copy
rt1 =rt.copy(deep=True)
rt1
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
#dropping unecessary columns
rt1.drop(["synopsis","writer","dvd_date","currency","runtime"],axis=1,inplace=True)

# %%
rt1
# Out:
#         id rating                                              genre  \
# 0        1      R                Action and Adventure|Classics|Drama
# 1        3      R                  Drama|Science Fiction and Fantasy
# 2        5      R                  Drama|Musical and Performing Arts
# 3        6      R                         Drama|Mystery and Suspense
# 4        7     NR                                      Drama|Romance
# ...    ...    ...                                                ...
# 1555  1996      R   Action and Adventure|Horror|Mystery and Suspense
# 1556  1997     PG                 Comedy|Science Fiction and Fantasy
# 1557  1998      G  Classics|Comedy|Drama|Musical and Performing Arts
# 1558  1999     PG    Comedy|Drama|Kids and Family|Sports and Fitness
# 1559  2000      R  Action and Adventure|Art House and Internation...
#
#                 director  theater_date  box_office             studio
# 0       William Friedkin   Oct 9, 1971         NaN                NaN
# 1       David Cronenberg  Aug 17, 2012     600,000  Entertainment One
# 2         Allison Anders  Sep 13, 1996         NaN                NaN
# 3         Barry Levinson   Dec 9, 1994         NaN                NaN
# 4         Rodney Bennett           NaN         NaN                NaN
# ...                  ...           ...         ...                ...
# 1555                 NaN  Aug 18, 2006  33,886,034    New Line Cinema
# 1556        Steve Barron  Jul 23, 1993         NaN  Paramount Vantage
# 1557      Gordon Douglas   Jan 1, 1962         NaN                NaN
# 1558  David Mickey Evans   Apr 1, 1993         NaN                NaN
# 1559                 NaN  Sep 27, 2001         NaN  Columbia Pictures
#
# [1560 rows x 7 columns]

# %%
#checking for missing values
rt1.isna().sum()
# Out:
# id                 0
# rating             3
# genre              8
# director         199
# theater_date     359
# box_office      1220
# studio          1066
# dtype: int64

# %%
#filling missing values for objects using mode
for column in rt1.select_dtypes(include=["object"]).columns:
    rt1[column].fillna(rt1[column].mode()[0],inplace=True)

# %%
#changing the box office values to numerical(box office sales a movie makes after its release)
#noted it was not numerical since it gave out an error when trying to fill missing values
# Step 1: Remove commas
rt1['box_office'] = rt1['box_office'].str.replace(',', '')

# Step 2: Convert to integers
rt1['box_office'] = rt1['box_office'].astype(int)

# %%
#checking for uniformity using a histogram
rt1.hist(bins=15,figsize=(5,5));

# %%
#filling in the missing values
rt1["box_office"]=rt1["box_office"].fillna(rt1["box_office"].median())

# %%
#confirming no missing values
rt1.isnull().sum().any()
# Out:
# False

# %%
rt1
# Out:
#         id rating                                              genre  \
# 0        1      R                Action and Adventure|Classics|Drama
# 1        3      R                  Drama|Science Fiction and Fantasy
# 2        5      R                  Drama|Musical and Performing Arts
# 3        6      R                         Drama|Mystery and Suspense
# 4        7     NR                                      Drama|Romance
# ...    ...    ...                                                ...
# 1555  1996      R   Action and Adventure|Horror|Mystery and Suspense
# 1556  1997     PG                 Comedy|Science Fiction and Fantasy
# 1557  1998      G  Classics|Comedy|Drama|Musical and Performing Arts
# 1558  1999     PG    Comedy|Drama|Kids and Family|Sports and Fitness
# 1559  2000      R  Action and Adventure|Art House and Internation...
#
#                 director  theater_date  box_office              studio
# 0       William Friedkin   Oct 9, 1971    20900803  Universal Pictures
# 1       David Cronenberg  Aug 17, 2012      600000   Entertainment One
# 2         Allison Anders  Sep 13, 1996    20900803  Universal Pictures
# 3         Barry Levinson   Dec 9, 1994    20900803  Universal Pictures
# 4         Rodney Bennett   Jan 1, 1987    20900803  Universal Pictures
# ...                  ...           ...         ...                 ...
# 1555    Steven Spielberg  Aug 18, 2006    33886034     New Line Cinema
# 1556        Steve Barron  Jul 23, 1993    20900803   Paramount Vantage
# 1557      Gordon Douglas   Jan 1, 1962    20900803  Universal Pictures
# 1558  David Mickey Evans   Apr 1, 1993    20900803  Universal Pictures
# 1559    Steven Spielberg  Sep 27, 2001    20900803   Columbia Pictures
#
# [1560 rows x 7 columns]

# %%
#converting the date time to year only for easier analysis
rt1["theater_date"]= pd.to_datetime(rt1["theater_date"]).dt.year

# %%
# Split 'genre' into 'main_genre' and 'supporting_genre', handling NaN values
rt1['main_genre'] = rt1['genre'].str.split('|').str[0]
rt1['supporting_genre'] = rt1['genre'].str.split('|').apply(
    lambda x: '|'.join(x[1:]) if isinstance(x, list) and len(x) > 1 else ''
)


# Preview the result
rt1[['genre', 'main_genre', 'supporting_genre']].head()
# Out:
#                                  genre            main_genre  \
# 0  Action and Adventure|Classics|Drama  Action and Adventure
# 1    Drama|Science Fiction and Fantasy                 Drama
# 2    Drama|Musical and Performing Arts                 Drama
# 3           Drama|Mystery and Suspense                 Drama
# 4                        Drama|Romance                 Drama
#
#               supporting_genre
# 0               Classics|Drama
# 1  Science Fiction and Fantasy
# 2  Musical and Performing Arts
# 3         Mystery and Suspense
# 4                      Romance

# %%
rt1
# Out:
#         id rating                                              genre  \
# 0        1      R                Action and Adventure|Classics|Drama
# 1        3      R                  Drama|Science Fiction and Fantasy
# 2        5      R                  Drama|Musical and Performing Arts
# 3        6      R                         Drama|Mystery and Suspense
# 4        7     NR                                      Drama|Romance
# ...    ...    ...                                                ...
# 1555  1996      R   Action and Adventure|Horror|Mystery and Suspense
# 1556  1997     PG                 Comedy|Science Fiction and Fantasy
# 1557  1998      G  Classics|Comedy|Drama|Musical and Performing Arts
# 1558  1999     PG    Comedy|Drama|Kids and Family|Sports and Fitness
# 1559  2000      R  Action and Adventure|Art House and Internation...
#
#                 director  theater_date  box_office              studio  \
# 0       William Friedkin          1971    20900803  Universal Pictures
# 1       David Cronenberg          2012      600000   Entertainment One
# 2         Allison Anders          1996    20900803  Universal Pictures
# 3         Barry Levinson          1994    20900803  Universal Pictures
# 4         Rodney Bennett          1987    20900803  Universal Pictures
# ...                  ...           ...         ...                 ...
# 1555    Steven Spielberg          2006    33886034     New Line Cinema
# 1556        Steve Barron          1993    20900803   Paramount Vantage
# 1557      Gordon Douglas          1962    20900803  Universal Pictures
# 1558  David Mickey Evans          1993    20900803  Universal Pictures
# 1559    Steven Spielberg          2001    20900803   Columbia Pictures
#
#                 main_genre                                   supporting_genre
# 0     Action and Adventure                                     Classics|Drama
# 1                    Drama                        Science Fiction and Fantasy
# 2                    Drama                        Musical and Performing Arts
# 3                    Drama                               Mystery and Suspense
# 4                    Drama                                            Romance
# ...                    ...                                                ...
# 1555  Action and Adventure                        Horror|Mystery and Suspense
# 1556                Comedy                        Science Fiction and Fantasy
# 1557              Classics           Comedy|Drama|Musical and Performing Arts
# 1558                Comedy           Drama|Kids and Family|Sports and Fitness
# 1559  Action and Adventure  Art House and International|Comedy|Drama|Myste...
#
# [1560 rows x 9 columns]

# %%
#dropping the unnecessary new column created
rt1.drop(["genre","supporting_genre"],axis=1,inplace=True)

# %%
rt1.rename({"main_genre":"genre"},axis=1,inplace=True)

# %%
rt1
# Out:
#         id rating            director  theater_date  box_office  \
# 0        1      R    William Friedkin          1971    20900803
# 1        3      R    David Cronenberg          2012      600000
# 2        5      R      Allison Anders          1996    20900803
# 3        6      R      Barry Levinson          1994    20900803
# 4        7     NR      Rodney Bennett          1987    20900803
# ...    ...    ...                 ...           ...         ...
# 1555  1996      R    Steven Spielberg          2006    33886034
# 1556  1997     PG        Steve Barron          1993    20900803
# 1557  1998      G      Gordon Douglas          1962    20900803
# 1558  1999     PG  David Mickey Evans          1993    20900803
# 1559  2000      R    Steven Spielberg          2001    20900803
#
#                   studio                 genre
# 0     Universal Pictures  Action and Adventure
# 1      Entertainment One                 Drama
# 2     Universal Pictures                 Drama
# 3     Universal Pictures                 Drama
# 4     Universal Pictures                 Drama
# ...                  ...                   ...
# 1555     New Line Cinema  Action and Adventure
# 1556   Paramount Vantage                Comedy
# 1557  Universal Pictures              Classics
# 1558  Universal Pictures                Comedy
# 1559   Columbia Pictures  Action and Adventure
#
# [1560 rows x 7 columns]

# %%
merged_movies_final_df.to_csv("merged movies.csv")

# %%
rt1.to_csv("movie ratings.csv")

# %%
merged_movies_final_df.head()
# Out:
#                              title                   genres  average_rating  \
# 0                            Wazir       Action,Crime,Drama             7.1
# 1                      On the Road  Adventure,Drama,Romance             6.1
# 2                      On the Road                    Drama             6.0
# 3                      On the Road                    Drama             5.7
# 4  The Secret Life of Walter Mitty   Adventure,Comedy,Drama             7.3
#
#    domestic_gross    foreign_gross  year      total_gross
# 0   $1,100,000.00   $18,700,000.00  2016   $19,800,000.00
# 1     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 2     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 3     $744,000.00    $8,000,000.00  2012    $8,744,000.00
# 4  $58,200,000.00  $129,900,000.00  2013  $188,100,000.00

# %%
rt1.head()
# Out:
#    id rating          director  theater_date  box_office              studio  \
# 0   1      R  William Friedkin          1971    20900803  Universal Pictures
# 1   3      R  David Cronenberg          2012      600000   Entertainment One
# 2   5      R    Allison Anders          1996    20900803  Universal Pictures
# 3   6      R    Barry Levinson          1994    20900803  Universal Pictures
# 4   7     NR    Rodney Bennett          1987    20900803  Universal Pictures
#
#                   genre
# 0  Action and Adventure
# 1                 Drama
# 2                 Drama
# 3                 Drama
# 4                 Drama

# %%
# Genre vs Rating 
genre_rating= merged_movies_final_df.groupby("genres")["average_rating"].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(5, 5))
sns.barplot(x=genre_rating.index, y=genre_rating.values,palette="Blues")
plt.xticks(rotation=45, ha='right')
plt.title('Genre vs Rating')
plt.show()

# %%
#Genre vs Sales
genre_sales= merged_movies_final_df.groupby("genres")["total_gross"].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(5, 5))
sns.barplot(x=genre_sales.index, y=genre_rating.values,palette="Blues")
plt.xticks(rotation=45, ha='right')
plt.title('Genre vs Sales')
plt.show()

# %%
#popular genres based on their count
merged_movies_final_df["genres"].value_counts().head(5).plot(kind='bar',figsize=(5,5))
sns.set_palette('Blues')
plt.title("popular genres")
plt.ylabel("counts")
plt.xlabel('genre')
plt.xticks(rotation=45);

# %%
#top movies based on genre popularity
top_three_movies = merged_movies_final_df["title"].value_counts().head(3).index

filtered_data = merged_movies_final_df[merged_movies_final_df["title"].isin(top_three_movies)]

top_genres=(
    filtered_data.groupby("title")["genres"]
    .value_counts()
    .groupby(level=0).nlargest(3)
    .reset_index(level=0,drop=True)
    .index.get_level_values(1)
)
    
filtered_data=filtered_data[filtered_data['genres'].isin(top_genres)]

plt.figure(figsize=(5, 5))#select figure size
sns.countplot(data=filtered_data, x='title', hue='genres')#selecting type of graph(countplot)
plt.title('Top 3 Movies with Top 3 Genres Vs popularity')#title for the graph
plt.xlabel('Movie')#x-axis label
plt.ylabel('Popularity')#y-axis label
plt.legend(title='Genres')#legend title
plt.legend(fontsize='small')  # You can use 'small', 'medium', 'large' or specify a number like 8 or 10

# Alternatively, you can control the size of the legend box:
plt.legend(handlelength=1, fontsize=8)  #
plt.show()#visualize the graph

# %%
#how genre with best rating has faired over the years(univariate analysis)
# Filter for the genre of interest
genre_of_interest = "Drama"
drama_df = merged_movies_final_df[merged_movies_final_df['genres'].str.contains(genre_of_interest, na=False)]

# Perform univariate analysis: Focus on average ratings over time
drama_yearly = drama_df.groupby('year')['average_rating'].mean()

# Plotting the univariate trend
plt.figure(figsize=(5, 5))
drama_yearly.plot(kind='line', marker='o', color='blue')
plt.title(f"Univariate Analysis: Drama Genre Ratings Over the Years", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.show();

# %%
gfh

# %%
#popular directors
director_popularity = rt1['director'].value_counts().head(5)
plt.figure(figsize=(5,5))
sns.barplot(x=director_popularity.index,y=director_popularity.values)
plt.title("most popular directors")
plt.xlabel("director")
plt.ylabel("count")
plt.xticks(rotation=45);

# %%
#best selling directors

# Group by director and sum the box office sales
director_sales = rt1.groupby("director")["box_office"].sum().sort_values(ascending=False).head(10)

# Create the plot
plt.figure(figsize=(5, 5))
sns.barplot(x=director_sales.values, y=director_sales.index, palette="Blues", orient="h")  # Horizontal bars

# Add title and labels
plt.xlabel('Box Office Sales')
plt.title('Directors vs Sales')

# Include x-tick labels (rotate for readability)
plt.xticks(rotation=60)

# Show the plot
plt.show()

# %%
#popular movie rating
rating_popularity = rt1['rating'].value_counts().head(5)
plt.figure(figsize=(5,5))
sns.barplot(x=rating_popularity.index,y=rating_popularity.values)
plt.title("most popular movie rating")
plt.xlabel("movie rating")
plt.ylabel("count")
plt.xticks(rotation=45);

# %%
#univariate analysis based on the highest selling director
# Filter for the genre of interest
highest_director = "Steven Spielberg"
director_df = rt1[rt1['director'].str.contains(highest_director, na=False)]

# Perform univariate analysis: Focus on average ratings over time
performance_yearly = director_df.groupby('theater_date')['box_office'].mean()

# Plotting the univariate trend
plt.figure(figsize=(5, 5))
drama_yearly.plot(kind='line', marker='o', color='blue')
plt.title(f"Univariate Analysis: Steven Spielberg's sales Over the Years", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.show()
